# %%
import pandas as pd

# %% [markdown]
# Instrucciones
# Lea los tres archivos en Python como marcos de datos
#
# Muestra la forma del DataFrame.

# %%
pd1=pd.read_csv(r"c:\Users\marco\OneDrive\Desktop\ironhack\Files\dia 3\file1 (1).csv")
pd2=pd.read_csv(r"c:\Users\marco\OneDrive\Desktop\ironhack\Files\dia 3\file2 (1).csv")
pd3=pd.read_csv(r"c:\Users\marco\OneDrive\Desktop\ironhack\Files\dia 3\file3.csv")

# %%
pd1.shape
# Out:
# (4008, 11)

# %%
pd2.shape
# Out:
# (996, 11)

# %%
pd3.shape
# Out:
# (7070, 11)

# %%
pd1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
pd2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
pd3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %% [markdown]
# Estandarizar los nombres de los encabezados.

# %%
pd3_1=pd3.rename(columns={"State":"ST"})

# %%
pd3_1
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
columnas=list(pd1.columns)

# %%
columnas
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
titulos_nuevos={}
for columna in columnas:
    titulos_nuevos[columna]=columna.upper()

# %%
titulos_nuevos
# Out:
# {'Customer': 'CUSTOMER',
#  'ST': 'ST',
#  'GENDER': 'GENDER',
#  'Education': 'EDUCATION',
#  'Customer Lifetime Value': 'CUSTOMER LIFETIME VALUE',
#  'Income': 'INCOME',
#  'Monthly Premium Auto': 'MONTHLY PREMIUM AUTO',
#  'Number of Open Complaints': 'NUMBER OF OPEN COMPLAINTS',
#  'Policy Type': 'POLICY TYPE',
#  'Vehicle Class': 'VEHICLE CLASS',
#  'Total Claim Amount': 'TOTAL CLAIM AMOUNT'}

# %%
pd1=pd1.rename(columns=titulos_nuevos)

# %%
columnas=list(pd2.columns)
titulos_nuevos2={}
for columna in columnas:
    titulos_nuevos2[columna]=columna.upper()
pd2=pd2.rename(columns=titulos_nuevos2)

# %%
columnas=list(pd3_1.columns)
titulos_nuevos3_1={}
for columna in columnas:
    titulos_nuevos3_1[columna]=columna.upper()
pd3_1=pd3_1.rename(columns=titulos_nuevos3_1)

# %% [markdown]
# Reorganice las columnas en el marco de datos según sea necesario

# %%
pd1[sorted(list(pd1.columns))] #para ordenarte alfabeticamente los titulos de las columnas
# Out:
#      CUSTOMER CUSTOMER LIFETIME VALUE             EDUCATION GENDER   INCOME  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 4003      NaN                     NaN                   NaN    NaN      NaN
# 4004      NaN                     NaN                   NaN    NaN      NaN
# 4005      NaN                     NaN                   NaN    NaN      NaN
# 4006      NaN                     NaN                   NaN    NaN      NaN
# 4007      NaN                     NaN                   NaN    NaN      NaN
#
# ...

# %%
pd2[sorted(list(pd2.columns))]
# Out:
#     CUSTOMER CUSTOMER LIFETIME VALUE EDUCATION GENDER  INCOME  \
# 0    GS98873              323912.47%  Bachelor      F   16061
# 1    CW49887              462680.11%    Master      F   79487
# 2    MY31220              899704.02%   College      F   54230
# 3    UH35128             2580706.30%   College      F   71210
# 4    WH52799              380812.21%   College      F   94903
# ..       ...                     ...       ...    ...     ...
# 991  HV85198              847141.75%    Master      M   63513
# 992  BS91566              543121.91%   College      F   58161
# 993  IL40123              568964.41%   College      F   83640
# 994  MY32149              368672.38%    Master      F       0
# 995  SA91515              399258.39%  Bachelor      M       0
#
#      MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS     POLICY TYPE  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# ...

# %%
pd3_1[sorted(list(pd3_1.columns))]
# Out:
#      CUSTOMER  CUSTOMER LIFETIME VALUE             EDUCATION GENDER  INCOME  \
# 0     SA25987              3479.137523  High School or Below      M       0
# 1     TB86706              2502.637401                Master      M       0
# 2     ZL73902              3265.156348              Bachelor      F   25820
# 3     KX23516              4455.843406  High School or Below      F       0
# 4     FN77294              7704.958480  High School or Below      M   30366
# ...       ...                      ...                   ...    ...     ...
# 7065  LA72316             23405.987980              Bachelor      M   71941
# 7066  PK87824              3096.511217               College      F   21604
# 7067  TD14365              8163.890428              Bachelor      M       0
# 7068  UP19263              7524.442436               College      M   21941
# 7069  Y167826              2611.836866               College      M       0
#
# ...

# %% [markdown]
# Concatenar los tres marcos de datos

# %%
# Concatenar los datos de las diferentes DataFreme
concatenar_datos = pd.concat([pd1, pd2, pd3_1], axis=0)

# %%
concatenar_datos
# Out:
#      CUSTOMER          ST GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
lista_concatenar_datos=list(concatenar_datos)
lista_concatenar_datos
# Out:
# ['CUSTOMER',
#  'ST',
#  'GENDER',
#  'EDUCATION',
#  'CUSTOMER LIFETIME VALUE',
#  'INCOME',
#  'MONTHLY PREMIUM AUTO',
#  'NUMBER OF OPEN COMPLAINTS',
#  'POLICY TYPE',
#  'VEHICLE CLASS',
#  'TOTAL CLAIM AMOUNT']

# %% [markdown]
# ¿Qué columnas son numéricas?
#
# ¿Qué columnas son categóricas?

# %%
# Sacar los tipos del DataFrame
tipos_columnas=concatenar_datos.dtypes
tipos_columnas
# Out:
# CUSTOMER                      object
# ST                            object
# GENDER                        object
# EDUCATION                     object
# CUSTOMER LIFETIME VALUE       object
# INCOME                       float64
# MONTHLY PREMIUM AUTO         float64
# NUMBER OF OPEN COMPLAINTS     object
# POLICY TYPE                   object
# VEHICLE CLASS                 object
# TOTAL CLAIM AMOUNT           float64
# dtype: object

# %%
list(tipos_columnas)
# Out:
# [dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64')]

# %%
colimnas_numericas = concatenar_datos.describe(include=['float','int'])
colimnas_numericas
# Out:
#              INCOME  MONTHLY PREMIUM AUTO  TOTAL CLAIM AMOUNT
# count   9137.000000           9137.000000         9137.000000
# mean   37828.820291            110.391266          430.527140
# std    30358.716159            581.376032          289.582968
# min        0.000000             61.000000            0.099007
# 25%        0.000000             68.000000          266.996814
# 50%    34244.000000             83.000000          377.561463
# 75%    62447.000000            109.000000          546.420009
# max    99981.000000          35354.000000         2893.239678

# %%
colimnas_categoricas = concatenar_datos.describe(include=['object'])
colimnas_categoricas
# Out:
#        CUSTOMER          ST GENDER EDUCATION  CUSTOMER LIFETIME VALUE  \
# count      9137        9137   9015      9137               9130.00000
# unique     9056           8      5         6               8211.00000
# top     QD28391  California      F  Bachelor              16468.22079
# freq          2        3032   4560      2719                  6.00000
#
#         NUMBER OF OPEN COMPLAINTS    POLICY TYPE  VEHICLE CLASS
# count                        9137           9137           9137
# unique                         12              3              6
# top                             0  Personal Auto  Four-Door Car
# freq                         5629           6792           4641

# %% [markdown]
# Realizar las operaciones de limpieza de datos mencionadas hasta ahora en clase.
#
# Elimine la columna educación y el número de quejas abiertas del marco de datos.
# Corrija los valores en la columna Valor de vida del cliente. Se dan como porcentaje, así que multiplíquelos por 100 y cámbielos dtypepara numericalescribirlos.
# Compruebe si hay filas duplicadas en los datos y elimínelas si las hay.
# Filtra los datos de los clientes que tienen un ingreso de 0 o menos.

# %%
#Eliminar celdas de DataFrame
eliminar_celdas = ['EDUCATION','NUMBER OF OPEN COMPLAINTS']

# %%
concatenar_datos.drop(eliminar_celdas, inplace=True, axis=1)

# %%
concatenar_datos
# Out:
#      CUSTOMER          ST GENDER CUSTOMER LIFETIME VALUE   INCOME  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
# Eliminar el signo de porcentaje y convertir los valores a números decimales
concatenar_datos['CUSTOMER LIFETIME VALUE'] = concatenar_datos['CUSTOMER LIFETIME VALUE']*100
# Multiplicar por 100 para obtener el valor real


print(concatenar_datos['CUSTOMER LIFETIME VALUE'])
# Out:
# 0                                                     NaN
# 1       697953.59%697953.59%697953.59%697953.59%697953...
# 2       1288743.17%1288743.17%1288743.17%1288743.17%12...
# 3       764586.18%764586.18%764586.18%764586.18%764586...
# 4       536307.65%536307.65%536307.65%536307.65%536307...
#                               ...
# 7065                                          234059879.8
# 7066                                          30965112.17
# 7067                                          81638904.28
# 7068                                          75244424.36
# 7069                                          26118368.66
# Name: CUSTOMER LIFETIME VALUE, Length: 12074, dtype: object

# %%
# Encontrar duplicados
duplicados = concatenar_datos[concatenar_datos.duplicated()]
duplicados
# Out:
#      CUSTOMER          ST GENDER  \
# 1072      NaN         NaN    NaN
# 1073      NaN         NaN    NaN
# 1074      NaN         NaN    NaN
# 1075      NaN         NaN    NaN
# 1076      NaN         NaN    NaN
# ...       ...         ...    ...
# 4006      NaN         NaN    NaN
# 4007      NaN         NaN    NaN
# 0     GS98873     Arizona      F
# 1     CW49887  California      F
# 2     MY31220  California      F
#
#                                 CUSTOMER LIFETIME VALUE   INCOME  \
# 1072                                                NaN      NaN
# 1073                                                NaN      NaN
# 1074                                                NaN      NaN
# 1075                                                NaN      NaN
# 1076                                                NaN      NaN
# ...                                                 ...      ...
# 4006                                                NaN      NaN
# ...

# %%
# Eliminar duplicados
df_limpio=concatenar_datos.drop_duplicates()
df_limpio
# Out:
#      CUSTOMER          ST GENDER  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 2     AI49188      Nevada      F
# 3     WW63253  California      M
# 4     GA49547  Washington      M
# ...       ...         ...    ...
# 7065  LA72316  California      M
# 7066  PK87824  California      F
# 7067  TD14365  California      M
# 7068  UP19263  California      M
# 7069  Y167826  California      M
#
#                                 CUSTOMER LIFETIME VALUE   INCOME  \
# 0                                                   NaN      0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...      0.0
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# 3     764586.18%764586.18%764586.18%764586.18%764586...      0.0
# 4     536307.65%536307.65%536307.65%536307.65%536307...  36357.0
# ...                                                 ...      ...
# 7065                                        2340598.798  71941.0
# ...

# %%
# Filtra los datos de los clientes que tienen un ingreso de 0 o menos.
df_limpio['INCOME']<=0
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067     True
# 7068    False
# 7069     True
# Name: INCOME, Length: 9135, dtype: bool

# %%
df_limpio[df_limpio['INCOME']<=0]
# Out:
#      CUSTOMER          ST GENDER  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 3     WW63253  California      M
# 7     CF85061     Arizona      M
# 10    SX51350  California      M
# ...       ...         ...    ...
# 7059  WZ45103  California      F
# 7061  RX91025  California      M
# 7062  AC13887  California      M
# 7067  TD14365  California      M
# 7069  Y167826  California      M
#
#                                 CUSTOMER LIFETIME VALUE  INCOME  \
# 0                                                   NaN     0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...     0.0
# 3     764586.18%764586.18%764586.18%764586.18%764586...     0.0
# 7     721610.03%721610.03%721610.03%721610.03%721610...     0.0
# 10    473899.20%473899.20%473899.20%473899.20%473899...     0.0
# ...                                                 ...     ...
# 7059                                        567805.0167     0.0
# ...
